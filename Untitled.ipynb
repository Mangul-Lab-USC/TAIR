# %%
import pandas as pd 
data_savant = pd.read_csv("GTEX_SaVanT.txt",sep='\t') 
data_savant.head()
# Out:
#                      sample  HBA_721_B_lymphoblasts  HBA_Adipocyte  \
# 0  GTEX.1117F.0426.SM.5EGHI                0.292699       0.743942
# 1  GTEX.1117F.0626.SM.5N9CS                0.550777       1.760130
# 2  GTEX.1117F.0726.SM.5GIEN                0.578434       1.458891
# 3  GTEX.1117F.1326.SM.5EGHH                0.775723       1.664025
# 4  GTEX.1117F.2426.SM.5EGGH                0.531634       1.227009
#
#    HBA_AdrenalCortex  HBA_Adrenalgland  HBA_Amygdala  HBA_Appendix  \
# 0           0.484423          0.455176      0.250221      1.042895
# 1           0.858623          0.867942      0.549833      2.119385
# 2           0.831372          0.840183      0.539575      1.885478
# 3           0.945667          0.982146      0.372426      2.118096
# 4           0.802531          0.838391      0.498293      1.969158
#
#    HBA_AtrioventricularNode  HBA_BDCA4+_DentriticCells  HBA_Bonemarrow  \
# 0                  0.910704                   0.244342        0.222023
# ...

# %%
import pandas as pd
data_imrep=pd.read_csv("TheAIR.CDR3.csv")
data_imrep.head()
# Out:
#    Unnamed: 0                      fileName                        sample  \
# 0           1       G16788.GTEX-QDVJ-0426.3       GTEX-QDVJ-0426-SM-2I5FW
# 1           2       G16790.GTEX-QEG4-0006.3       GTEX-QEG4-0006-SM-2I5FY
# 2           3       G16791.GTEX-QEG5-0006.3       GTEX-QEG5-0006-SM-2I5FZ
# 3           4       G16794.GTEX-QLQ7-0526.3       GTEX-QLQ7-0526-SM-2I5G3
# 4           5  G16802.GTEX-OXRN-0011-R10A.3  GTEX-OXRN-0011-R10A-SM-2I5GC
#
#   individual                        tissue  raw.single.reads  nIGH  nIGK  \
# 0  GTEX-QDVJ        Heart - Left Ventricle         135986666     7     3
# 1  GTEX-QEG4                   Whole Blood         138173333   128    25
# 2  GTEX-QEG5                   Whole Blood         135413333   194    20
# 3  GTEX-QLQ7        Heart - Left Ventricle         160000000     4     3
# 4  GTEX-OXRN  Brain - Frontal Cortex (BA9)         150093333     2     2
#
#    nIGL  nTCRA         ...           alphaTCRG   CPM.IGH   CPM.IGK   CPM.IGL  \
# ...

# %%
metadata=pd.read_csv('./metadata/curated.metadata.RNASeq.samples.8555.csv')
metadata.head()
# Out:
#                            fileName                        sample  individual  \
# 0      G56254.GTEX-13112-0011-R5b.2  GTEX-13112-0011-R5b-SM-5DUV8  GTEX-13112
# 1          G62434.GTEX-14E7W-0006.2      GTEX-14E7W-0006-SM-5N9GG  GTEX-14E7W
# 2  G25695.GTEX-NFK9-0326-SM-3MJGV.1       GTEX-NFK9-0326-SM-3MJGV   GTEX-NFK9
# 3      G65595.GTEX-13SLW-0011-R8b.3  GTEX-13SLW-0011-R8b-SM-5SI64  GTEX-13SLW
# 4      G63111.GTEX-13X6J-0011-R6a.2  GTEX-13X6J-0011-R6a-SM-5PNUB  GTEX-13X6J
#
#                                       tissue  raw.single.reads
# 0            Brain - Caudate (basal ganglia)          70066666
# 1                                Whole Blood          94613333
# 2                     Adipose - Subcutaneous         114480000
# 3                       Brain - Hypothalamus          76933333
# 4  Brain - Nucleus accumbens (basal ganglia)          88933333

# %%
data=pd.merge( data_savant,metadata, on='sample')
data.head()


#select samples present in metdata nd filter Savant
# Out:
# Empty DataFrame
# ...
